# %% [markdown]
# ![Laplace's generalization of the Fourier transform](../images/laplace_generalization.png)
# [ 🎞️ Zach Star: The intuition behind Fourier and Laplace transforms I was never taught in school](https://youtu.be/3gjJDuCAEQQ?si=Sq1TuGWEbVpe7pyJ&t=850)
