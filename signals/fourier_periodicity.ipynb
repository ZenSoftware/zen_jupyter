# %% [markdown]
# ## 🎵 Big Picture
# - **Fourier Series** → frequency decomposition of **periodic** signals
# - **Fourier Transform** → frequency decomposition of **non‑periodic** or **arbitrary** signals
#
# They’re siblings, not strangers. In fact, the Fourier transform is what you get when the period of a Fourier series goes to infinity.
#
# ---
#
# ## 🧩 When to Use Each
#
# ### **Fourier Series**
# Used when:
# - The signal repeats every $T$ units.
# - You want to express it as a sum of harmonics:
#   $$
#   f(t) = \sum_{n=-\infty}^{\infty} c_n e^{i n \omega_0 t}
#   $$
# - Frequencies are **discrete**:
#   $\omega_n = n \omega_0$, where $\omega_0 = \frac{2\pi}{T}$
#
# Think of it as a **recipe with a countable list of ingredients**.
#
# ---
#
# ### **Fourier Transform**
# Used when:
# - The signal is **not periodic** (or you want to treat it as such).
# - You want a continuous spectrum:
#   $$
#   F(\omega) = \int_{-\infty}^{\infty} f(t)\, e^{-i\omega t}\, dt
#   $$
# - Frequencies are **continuous**.
#
# This is like a **smooth color gradient** instead of discrete stripes.
#
# ---
#
# ## 🔍 Key Differences at a Glance
#
# | Feature | Fourier Series | Fourier Transform |
# |--------|----------------|-------------------|
# | Signal type | Periodic | Non‑periodic |
# | Frequency spectrum | Discrete (harmonics) | Continuous |
# | Representation | Sum of exponentials | Integral over all frequencies |
# | Domain | One period | Entire real line |
# | Coefficients | $c_n$ | $F(\omega)$ |
#
# ---
#
# ## 🧠 Intuition (the part that really sticks)
# Imagine plucking a guitar string:
#
# - If the vibration repeats perfectly → **Fourier series** describes it with a set of harmonics.
# - If you play a single non‑repeating note or a transient sound → **Fourier transform** captures its full continuous spectrum.
#
# Or mathematically:
#
# - A periodic function is like a **crystal lattice** → discrete spectrum.
# - A non‑periodic function is like a **single atom** → continuous spectrum.
#
# ---
#
# ## 🌉 The Bridge Between Them
# If you take a periodic function with period $T$ and let $T \to \infty$:
#
# - The spacing between harmonics $\omega_0 = \frac{2\pi}{T}$ shrinks.
# - The discrete spectrum becomes continuous.
# - The Fourier series becomes the Fourier transform.
#
# This is one of those beautiful “limits reveal structure” moments that I know you appreciate.

# %% [markdown]
# ---
#
# # 🎯 A signal can be periodic or non‑periodic — but **sinusoids themselves are always periodic**
# So the difference between Fourier series and Fourier transform is **not** about whether the component sinusoids are periodic. They always are.
#
# The difference is about **how many** sinusoids you need and **how their frequencies are arranged**.
#
# Let’s unpack that cleanly.
#
# ---
#
# # 🧠 1. Sinusoids are always periodic
# Every building block in Fourier analysis is a sinusoid:
#
# $$
# e^{i\omega t}
# $$
#
# This function is periodic for any fixed $\omega$.
# So yes — the *components* are always periodic.
#
# But the **signal you build from them does not have to be periodic**.
#
# ---
#
# # 🧩 2. How can periodic components create a non‑periodic signal?
# Two ways:
#
# ### **A. You use a continuum of frequencies**
# A Fourier transform uses *every* frequency $\omega\in\mathbb{R}$.
# When you integrate over all frequencies:
#
# $$
# f(t) = \int_{-\infty}^{\infty} F(\omega)e^{i\omega t}\,d\omega
# $$
#
# the result is generally **not periodic**, even though each individual sinusoid is.
#
# It’s like mixing infinitely many pure tones — the interference pattern no longer repeats.
#
# ---
#
# ### **B. You use frequencies that are not harmonically related**
# A Fourier series uses frequencies that are integer multiples of a base frequency:
#
# $$
# \omega_n = n\omega_0
# $$
#
# This harmonic structure forces the signal to repeat every $T = \frac{2\pi}{\omega_0}$.
#
# But a Fourier transform uses **arbitrary** frequencies.
# If the frequencies don’t line up as integer multiples, the sum never repeats.
#
# ---
#
# # 🎨 Intuition you’ll appreciate
# Think of periodicity like tiling a floor.
#
# - **Fourier series** uses tiles that fit perfectly into a repeating pattern.
#   The signal repeats because the frequencies are locked into a lattice.
#
# - **Fourier transform** uses tiles of every possible size.
#   You can still build the floor, but the pattern never repeats.
#
# The tiles (sinusoids) are periodic — the floor (signal) doesn’t have to be.
#
# ---
#
# # 🧠 3. So what’s the real difference?
#
# ### **Fourier series**
# - Uses **discrete** frequencies
# - Frequencies are **harmonics**
# - Signal is **periodic**
#
# ### **Fourier transform**
# - Uses a **continuous** spectrum
# - Frequencies are **not harmonically constrained**
# - Signal is **not periodic**
#
# The periodicity of the *components* never changes — only the **structure of the frequency set** changes.
#
# ---
#
# # 🎯 Final clarity
# **The signal can be non‑periodic even though its sinusoidal components are periodic.**
# What matters is whether the frequencies form a discrete harmonic set (series) or a continuous arbitrary set (transform).

# %% [markdown]
# ---
#
# Absolutely — and your confusion is **totally justified**. The clean way to understand this is:
#
# # 🎯 **Yes, the Fourier transform *can* analyze both periodic and nonperiodic signals.**
# The distinction people make (“Fourier series for periodic, Fourier transform for nonperiodic”) is **not about capability**, but about **convenience and mathematical form**.
#
# Let’s untangle the relationship so it finally feels intuitive.
#
# ---
#
# # 🧩 **1. Fourier Series vs. Fourier Transform: What they *assume***
# ### **Fourier Series**
# - Assumes the signal is **periodic**.
# - Represents it using **discrete harmonics**.
# - Frequencies are integer multiples of a fundamental.
#
# $$
# x(t) = \sum_{k=-\infty}^{\infty} c_k e^{jk\omega_0 t}
# $$
#
# ### **Fourier Transform**
# - Assumes the signal is **not necessarily periodic**.
# - Represents it using a **continuous spectrum**.
#
# $$
# X(\omega) = \int_{-\infty}^{\infty} x(t)e^{-j\omega t}\,dt
# $$
#
# So the difference is about **assumptions**, not **capability**.
#
# ---
#
# # 🎵 **2. What happens if you apply the Fourier transform to a periodic signal?**
#
# You *can* take the Fourier transform of a periodic signal — and when you do, something elegant happens:
#
# ### A periodic signal’s Fourier transform becomes a **train of delta spikes** at harmonic frequencies.
#
# $$
# X(\omega) = 2\pi \sum_{k=-\infty}^{\infty} c_k \delta(\omega - k\omega_0)
# $$
#
# This is exactly the Fourier series coefficients, just expressed in transform form.
#
# So the Fourier transform **does work** for periodic signals — it simply produces a *discrete* spectrum.
#
# ---
#
# # 🔄 **3. Deep duality: Periodic ↔ Discrete**
# This is the heart of the matter:
#
# | Time Domain | Frequency Domain |
# |-------------|------------------|
# | **Periodic** | **Discrete (impulses)** |
# | **Nonperiodic** | **Continuous** |
#
# This duality is why Fourier series and Fourier transforms look different — they’re describing different structural cases.
#
# ---
#
# # 🧠 **4. So why do textbooks separate them?**
#
# Because:
#
# - For periodic signals, the Fourier series is **simpler** and gives you **just the harmonics**.
# - For nonperiodic signals, the Fourier transform is the natural tool.
#
# But mathematically, the Fourier transform is more general — it includes the Fourier series as a special case.
#
# ---
#
# # 🎤 **5. The cleanest summary**
# - **Fourier series**: best tool *when the signal is periodic*.
# - **Fourier transform**: works for *any* signal (periodic or not).
# - When applied to a periodic signal, the Fourier transform produces **delta spikes at harmonic frequencies**, which is exactly the Fourier series in disguise.
