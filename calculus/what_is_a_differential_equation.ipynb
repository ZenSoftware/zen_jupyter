# %% [markdown]
# # 📏 What is a differential equation
#
# A differential equation is an equation that relates an **unknown function** to one or more of its **derivatives**. In other words, it describes how something changes rather than just what it is.
#
# A clean, grounded definition:
#
# ## 📘 What it is
# A differential equation is *“an equation that relates one or more unknown functions and their derivatives.”*
# Derivatives represent **rates of change**, so differential equations express how a quantity evolves over time, space, or another variable.
#
# ## 🧠 Why they matter
# Many natural and engineered systems are governed by relationships between a quantity and its rate of change. That’s why differential equations appear in:
# - physics (motion, heat, electricity)
# - biology (population growth)
# - engineering (circuits, vibrations)
# - economics (growth models)
#
# ## 🧩 Simple examples
# - $ \frac{dy}{dt} = ky $
#   Models exponential growth or decay.
# - $ m\frac{d^2x}{dt^2} = F(x,t) $
#   Newton’s second law written as a differential equation.
# - $ \frac{dN}{dt} = rN $
#   Population growth model.
#
# ## 🗂️ Types (at a glance)
# - **Ordinary differential equations (ODEs):** derivatives with respect to one variable.
# - **Partial differential equations (PDEs):** derivatives with respect to multiple variables.
# - **Linear vs. nonlinear:** depends on how the unknown function appears.

# %% [markdown]
# ---
#
# **In a differential equation, you are not *actually* taking the derivative yourself.
# You are writing down a relationship that the *unknown function* must satisfy.**
#
# Let’s unpack that in a way that feels intuitive.
#
# ---
#
# # 🌱 Think of it like a puzzle with missing pieces
# A differential equation doesn’t *compute* a derivative.
# It *states a rule* that the correct function must obey.
#
# For example:
#
# $$
# \frac{dy}{dt} = 3y
# $$
#
# This equation says:
#
# > “Whatever the function $y(t)$ is, its rate of change must always be three times its current value.”
#
# You don’t need to know $y(t)$ yet.
# You’re describing a **constraint** that the true function must satisfy.
#
# Solving the differential equation means:
#
# > “Find all functions whose derivative is three times themselves.”
#
# And indeed, the solution is:
#
# $$
# y(t) = Ce^{3t}
# $$
#
# ---
#
# # 🔧 Analogy: A lock before you know the key
# A differential equation is like describing the shape of a lock:
#
# - You don’t know the key yet (the function).
# - But you know the rules the key must follow to fit the lock (the relationship between the function and its derivative).
#
# Solving the differential equation is finding the key that fits.
#
# ---
#
# # 🧠 Why this works mathematically
# When you write something like:
#
# $$
# y' + y = 0
# $$
#
# You are not *computing* $y'$.
# You are saying:
#
# > “Find a function $y(t)$ such that when you take its derivative and add it to itself, the result is zero.”
#
# This is a **condition**, not a computation.
#
# It’s the same idea as writing:
#
# $$
# x^2 - 4 = 0
# $$
#
# You don’t know $x$ yet, but you can still write an equation involving it.
#
# ---
#
# # 🔍 A helpful comparison
# | Type of equation | Unknown | What the equation expresses |
# |------------------|---------|-----------------------------|
# | Algebraic        | number $x$ | A relationship between numbers |
# | Differential     | function $y(t)$ | A relationship between a function and its derivatives |
#
# In both cases, you write the equation *before* you know the solution.
#
# ---
#
# # 🌟 The key insight
# You **don’t** need to know the function to write a differential equation.
# You only need to know the **relationship** between the function and its rate of change.
#
# The *solution* to the differential equation is the function that makes that relationship true.

# %% [markdown]
# ---
#
# > The process that you just did, is this called taking an antiderivative?
#
# You’re right to notice the similarity — solving a simple differential equation *can* look like taking an antiderivative. But the two ideas aren’t the same, even though they overlap.
#
# Let’s untangle them clearly.
#
# ---
#
# # 🌿 Short answer
# **Sometimes solving a differential equation involves taking an antiderivative, but the process itself is not “taking an antiderivative.”**
#
# An antiderivative is a *specific operation*.
# Solving a differential equation is a *broader task* that may use that operation as one step.
#
# ---
#
# # 🔍 Why it *looks* like an antiderivative
# Take the example:
#
# $$
# \frac{dy}{dt} = y
# $$
#
# If you separate variables:
#
# $$
# \frac{1}{y} \, dy = dt
# $$
#
# Now integrate both sides:
#
# $$
# \int \frac{1}{y} \, dy = \int dt
# $$
#
# This gives:
#
# $$
# \ln|y| = t + C
# $$
#
# Then solve for $y$:
#
# $$
# y = Ce^{t}
# $$
#
# Yes — we used **integration** (antiderivatives) as part of the solution.
# But notice:
#
# - We weren’t just finding the antiderivative of a known function.
# - We were finding a function $y(t)$ that satisfies a *relationship*.
#
# That’s a bigger job.
#
# ---
#
# # 🌱 What an antiderivative actually is
# An antiderivative answers the question:
#
# > “Given a function $f(x)$, find a function $F(x)$ whose derivative is $f(x)$.”
#
# Example:
#
# $$
# \int x^2 \, dx = \frac{x^3}{3} + C
# $$
#
# Here, the function is known ahead of time.
#
# ---
#
# # 🌳 What solving a differential equation is
# A differential equation asks:
#
# > “Find all functions $y(t)$ that satisfy this relationship involving derivatives.”
#
# The function is *not* known ahead of time — you’re discovering it.
#
# Sometimes that discovery involves integration.
# Sometimes it involves algebra, substitution, linear algebra, transforms, or other tools.
#
# ---
#
# # 🌟 A helpful way to see the difference
# - **Antiderivative:** You already know the function. You just want its reverse derivative.
# - **Differential equation:** You don’t know the function. You’re finding it by solving a rule it must obey.
#
# ---
#
# Let’s make the distinction crystal clear by looking at a differential equation where **solving it is *not* the same thing as taking an antiderivative**. This usually makes the difference “click.”
#
# ---
#
# # 🌟 Example: A differential equation that cannot be solved by simple antiderivatives
#
# Consider this differential equation:
#
# $$
# y' + y = 0
# $$
#
# This is one of the simplest linear differential equations, but solving it is **not** the same as taking an antiderivative of a known function.
#
# Let’s walk through it slowly.
#
# ---
#
# # 🔍 Step 1: Notice what you *don’t* know
# You don’t know $y(t)$.
# You don’t know $y'(t)$.
# You only know the **relationship**:
#
# > “The derivative of the function plus the function itself must equal zero.”
#
# This is a *rule*, not a computation.
#
# ---
#
# # 🔧 Step 2: Rearrange the relationship
# $$
# y' = -y
# $$
#
# This says:
#
# > “The rate of change of the function is always the negative of the function.”
#
# Still no actual function — just a rule.
#
# ---
#
# # 🔁 Step 3: Separate variables
# $$
# \frac{dy}{dt} = -y
# $$
#
# $$
# \frac{1}{y} \, dy = -dt
# $$
#
# Now we integrate both sides:
#
# $$
# \int \frac{1}{y} \, dy = \int -dt
# $$
#
# This step *uses* antiderivatives, but the goal is not “find the antiderivative of a known function.”
# The goal is “find a function $y(t)$ that satisfies the rule.”
#
# ---
#
# # 📘 Step 4: Integrate
# $$
# \ln|y| = -t + C
# $$
#
# Now solve for $y$:
#
# $$
# y = Ce^{-t}
# $$
#
# This is the **solution** to the differential equation.
#
# ---
#
# # 🌱 Why this is *not* just taking an antiderivative
# Compare the two processes:
#
# ## ✔️ Antiderivative
# You start with a known function, like:
# $$
# f(t) = t^2
# $$
# and you compute:
# $$
# \int t^2 dt = \frac{t^3}{3} + C
# $$
#
# You already knew the function.
# You just reversed differentiation.
#
# ---
#
# ## ✔️ Differential equation
# You start with a *relationship*, like:
# $$
# y' + y = 0
# $$
#
# You don’t know the function.
# You don’t know its derivative.
# You’re not reversing a known derivative.
#
# You’re discovering **all functions that satisfy the rule**.
#
# The integration step is just one tool in the process — not the goal.
#
# ---
#
# # 🌟 A simple analogy
# - **Antiderivative:**
#   You know the destination, and you’re finding the road that leads there.
#
# - **Differential equation:**
#   You only know the rules of the road, and you’re discovering what destinations are possible.
#
# ---
#
# # If you want, we can go one step further
# I can show you a differential equation that **cannot** be solved by separation of variables or simple integration at all — something that really highlights the difference.
