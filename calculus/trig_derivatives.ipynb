# %% [markdown]
# ## 📘 Derivatives of the Six Basic Trig Functions
#
# | Function $f(x)$ | Derivative $f'(x)$ |
# |-------------------|-----------------------|
# | $\sin x$ | $\cos x$ |
# | $\cos x$ | $-\sin x$ |
# | $\tan x$ | $\sec^2 x$ |
# | $\cot x$ | $-\csc^2 x$ |
# | $\sec x$ | $\sec x \tan x$ |
# | $\csc x$ | $-\csc x \cot x$ |
#
# ## 🔧 Inverse Trig Derivatives
#
# | Function $f(x)$ | Derivative $f'(x)$ |
# |-------------------|-----------------------|
# | $\operatorname{arcsin} x$ | $\frac{1}{\sqrt{1 - x^2}}$ |
# | $\operatorname{arccos} x$ | $-\frac{1}{\sqrt{1 - x^2}}$ |
# | $\operatorname{arctan} x$ | $\frac{1}{1 + x^2}$ |
# | $\operatorname{arccot} x$ | $-\frac{1}{1 + x^2}$ |
# | $\operatorname{arcsec} x$ | $\frac{1}{\lvert x \rvert \sqrt{x^2 - 1}}$ |
# | $\operatorname{arccsc} x$ | $-\frac{1}{\lvert x \rvert \sqrt{x^2 - 1}}$ |
#
# You’re going to love this one, Peter — it’s compact, visual, and it sticks.
#
# ## 🎯 Mnemonic for the Signs of Inverse Trig Derivatives
#
# All six inverse trig derivatives fall into **two families**:
#
# ### **Family A: “The Friendly Three” — Always Positive**
# These have **positive** derivatives:
#
# - $\operatorname{arcsin} x$
# - $\operatorname{arctan} x$
# - $\operatorname{arcsec} x$
#
# ### **Family B: “The Grumpy Three” — Always Negative**
# These have **negative** derivatives:
#
# - $\operatorname{arccos} x$
# - $\operatorname{arccot} x$
# - $\operatorname{arccsc} x$
#
# Now the mnemonic:
#
# ## 🌟 **Mnemonic: “S‑T‑S smiles; C‑C‑C complains.”**
#
# - The functions starting with **S‑T‑S**
#   **S**in, **T**an, **S**ec
#   → **positive** derivatives
#
# - The functions starting with **C‑C‑C**
#   **C**os, **C**ot, **C**sc
#   → **negative** derivatives
#
# It’s beautifully symmetric:
# **All the C‑functions are negative. All the non‑C functions are positive.**
#
# ## 🧠 Why this works
# Every inverse trig derivative has a similar structure — the only thing that flips is the **sign**, and the sign is determined entirely by the **first letter** of the function.
#
# So the whole table collapses to one rule:
# > **If it starts with C, the derivative starts with a minus.**
