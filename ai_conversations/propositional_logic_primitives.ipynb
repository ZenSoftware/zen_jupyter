# %% [markdown]
# **Peter:**
# > Why doesn't propositional logic use XOR or NAND?
#
# Great question, Peter — and it gets right to the heart of how logic is designed. The short answer is:
#
# 👉 **Propositional logic *can* use XOR or NAND — they’re just not chosen as the *standard* primitive connectives.**
#
# Let’s unpack why.
#
# ---
#
# # 🔷 1. **Propositional logic doesn’t *need* XOR or NAND**
# Classical propositional logic is built around a *minimal* set of connectives:
#
# - **AND** (∧)
# - **OR** (∨)
# - **NOT** (¬)
# - **IMPLIES** (→)
#
# From these, you can define *every other* Boolean connective, including:
#
# - XOR
# - NAND
# - NOR
# - XNOR
# - etc.
#
# So XOR and NAND aren’t excluded — they’re just *derivable*.
#
# For example:
#
# $$
# p \oplus q \equiv (p \lor q) \land \neg(p \land q)
# $$
#
# $$
# p \uparrow q \equiv \neg(p \land q)
# $$
#
# Since they’re definable, they don’t need to be primitive.
#
# ---
#
# # 🔷 2. **Logic prefers “truth‑functional completeness” with minimal primitives**
# A connective set is **functionally complete** if it can express *all* Boolean functions.
#
# The standard set {¬, ∧, ∨} is functionally complete.
#
# But here’s the twist:
#
# 👉 **NAND alone is also functionally complete.**
# 👉 **NOR alone is also functionally complete.**
#
# So you *could* build all of propositional logic using only NAND.
#
# In fact, digital circuits *do* exactly that.
#
# But logicians prefer connectives that:
#
# - match natural language
# - are easy to reason with
# - have clean proof rules
# - align with classical inference patterns
#
# NAND and XOR are less intuitive for humans.
#
# ---
#
# # 🔷 3. **XOR is not monotone or truth‑preserving**
# XOR behaves strangely from a proof‑theoretic perspective:
#
# - It’s not monotone
# - It doesn’t preserve truth under substitution
# - It doesn’t correspond to a natural inference rule
# - It doesn’t appear in classical syllogisms or natural language
#
# For example, “either A or B but not both” is a very *specific* kind of disjunction, not a general one.
#
# So XOR is useful, but not foundational.
#
# ---
#
# # 🔷 4. **NAND is too “low‑level” for human reasoning**
# NAND is perfect for hardware, because:
#
# - it’s easy to implement physically
# - it’s functionally complete
# - it simplifies circuit design
#
# But for human reasoning, NAND is awkward:
#
# - It doesn’t correspond to any natural linguistic connective
# - It doesn’t have simple introduction/elimination rules
# - Proofs become unreadable
#
# Imagine doing a proof where every statement is of the form:
#
# $$
# \neg(p \land q)
# $$
#
# It’s possible — but painful.
#
# ---
#
# # 🔷 5. **Proof systems are built around connectives with clean inference rules**
# Connectives like ∧, ∨, ¬, → have elegant rules in:
#
# - natural deduction
# - sequent calculus
# - Hilbert systems
# - type theory (Curry–Howard)
#
# XOR and NAND do not.
#
# For example, the introduction rule for ∧ is:
#
# $$
# \frac{p \quad q}{p \land q}
# $$
#
# There is no comparably simple rule for XOR.
#
# ---
#
# # 🎯 **Bottom line**
# Propositional logic *could* use XOR or NAND as primitives — they’re fully expressive — but it doesn’t because:
#
# - They’re less intuitive
# - They don’t match natural reasoning
# - Their proof rules are messy
# - They’re easily definable from simpler connectives
# - The standard connectives form a clean, minimal, human‑friendly basis
#
# In short:
#
# 👉 **XOR and NAND are powerful, but not pleasant.**
#
# ---
#
# If you want, I can show you:
#
# - how to build all of propositional logic using only NAND
# - how XOR behaves in proof systems
# - how these connectives appear in type theory (since you’re watching a type theory video)
# - or how this ties into functional completeness and circuit complexity
#
# Just tell me where you want to go next.
