# %% [markdown]
# - Beta
# - Student's t
# - Rayleigh distribution
#   - Maxwell distribution (3D version)
#   - Rice distribution (when the mean isn’t zero)
#
# [From Iaian Explains Signals](https://www.youtube.com/watch?v=W28-96AhF2s&list=PLx7-Q20A1VYKRLHUMSt2YOORrVz8iH-Kq)
# - Stationary Random Process
# - Autocorrelation
# - Power Spectral Density
# - Wide Sense Stationary
# - Are Stationary Random Processes Always Ergodic
