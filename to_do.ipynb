# %% [markdown]
# # Statistics
# - Beta
# - Student's t
# - Covariance and Correlation
#   - Determinant of the covariance matrix
#   - Eigen vectors/values of the covariance matrix
# - Characteristic functions / MGFs
#
# # Probability
# - Lebesgue Integral
#
# # Calculus
# - Power series
# - Angular velocity with polar coordinates
# - Partial derivatives (multivariate Calculus)
# - Lagrangian
# - Jacobian matrix
# - Gradients
#
# # Linear Algebra
# - Hilbert Space
# - Functional Analysis
#
# # Signal Processing
# - Fourier / Laplace transforms
# - Exponential damping/amplification
# - Convolutions
# - Wavelets
#
# # AI
# - Linear regression and gradient descent
