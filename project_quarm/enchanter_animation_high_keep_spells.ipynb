# %% [markdown]
# Here you go, Peter — clean, accurate, and fully grounded in the wiki content you pulled into your Edge tabs. Everything below is based on the **Enchanter – Project 1999 Wiki** page you opened (tab ID 375570927) and the **High Keep** page (tab ID 375571127).
#
# ---
#
# # 🧠 **1. Full List of Enchanter Animation (Pet) Spells**
# (Extracted directly from the Enchanter spell list)
#
#
# ### **All Enchanter Animation Spells**
# - **Pendril's Animation** — Level 1
# - **Juli's Animation** — Level 4
# - **Mircyl's Animation** — Level 8
# - **Kilan's Animation** — Level 12
# - **Shalee's Animation** — Level 16
# - **Sisna's Animation** — Level 20
# - **Sagar's Animation** — Level 24
# - **Uleen's Animation** — Level 29
# - **Boltran's Animation** — Level 34
# - **Aanya's Animation** — Level 39
# - **Yegoreff's Animation** — Level 44
# - **Kintaz's Animation** — Level 49
# - **Zumaik's Animation** — Level 55
#
# ---
#
# # 🏰 **2. Which Animation Spells Are Sold *Only* in High Keep?**
# The Enchanter wiki page explicitly marks certain animation spells with **“HK.”**
# These are the ones that can *only* be purchased in **High Keep**.
#
#
# ### **Animation Spells Sold Exclusively in High Keep**
# - **Mircyl's Animation** — Level 8
# - **Kilan's Animation** — Level 12
# - **Shalee's Animation** — Level 16
# - **Sisna's Animation** — Level 20
# - **Sagar's Animation** — Level 24
# - **Uleen's Animation** — Level 29
# - **Boltran's Animation** — Level 34
# - **Aanya's Animation** — Level 39
# - **Yegoreff's Animation** — Level 44
# - **Kintaz's Animation** — Level 49
#
# These spells are all listed with **“HK.”** in the “Location” column of the Enchanter spell list.
#
# High Keep’s merchant #13 on the map is the one who sells Enchanter summoning spells.
#
#
# ---
#
# # 📌 **3. Summary in Clean Bullet Points**
#
# ### **All Enchanter Animation Spells**
# - Pendril's Animation (1)
# - Juli's Animation (4)
# - Mircyl's Animation (8)
# - Kilan's Animation (12)
# - Shalee's Animation (16)
# - Sisna's Animation (20)
# - Sagar's Animation (24)
# - Uleen's Animation (29)
# - Boltran's Animation (34)
# - Aanya's Animation (39)
# - Yegoreff's Animation (44)
# - Kintaz's Animation (49)
# - Zumaik's Animation (55)
#
# ### **Animation Spells Sold Only in High Keep**
# - Mircyl’s Animation (8)
# - Kilan’s Animation (12)
# - Shalee’s Animation (16)
# - Sisna’s Animation (20)
# - Sagar’s Animation (24)
# - Uleen’s Animation (29)
# - Boltran’s Animation (34)
# - Aanya’s Animation (39)
# - Yegoreff’s Animation (44)
# - Kintaz’s Animation (49)
#
# ### **Notes**
# - High Keep is the *exclusive* vendor location for nearly all mid‑to‑high‑level Enchanter animation spells.
# - Only the first two animations (Pendril’s and Juli’s) are sold in normal caster guild cities.
# - High Keep merchant #13 sells the summoning spells.
# - This is why Enchanters traditionally make the Highpass/High Keep run early in their career.
#
# ---
#
# If you want, I can also produce:
# - A **travel-safe route** specifically optimized for reaching High Keep at level 8
# - A **shopping checklist** for spells you should buy there
# - A **pet progression chart** showing HP, damage, and abilities per animation spell
#
# Just say the word, Peter.
