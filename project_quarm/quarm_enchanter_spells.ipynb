# %% [markdown]
# You’re asking exactly the right question, Peter — because **Project Quarm does NOT follow Project 1999’s classic-era Research system**, and the difference matters a lot for Enchanters.
#
# Using the **Enchanter Spells** page you have open , we can cross‑reference every spell in your level range and determine which ones are:
#
# - **Vendor‑bought**
# - **Research‑only on P99 but vendor‑bought on Quarm**
# - **Still research‑only on Quarm**
# - **Dropped**
# - **Quested**
#
# Here’s the clean breakdown.
#
# ---
#
# # 🌟 The Big Picture:
# ## **Project Quarm uses the Luclin/PoP-era spell distribution, NOT classic-era research.**
#
# That means:
#
# ### ✔️ **Most “research-only” Enchanter spells from P99 are vendor spells on Quarm.**
# ### ✔️ **You will NOT need to research your core charm, mez, or utility spells.**
# ### ✔️ **Only a handful of high-level spells remain research-only or drop-only.**
#
# This is a *huge* quality-of-life improvement over P99.
#
# ---
#
# # 📘 Cross‑Reference: Your Early-Level Spells (1–29)
#
# Looking at the **Enchanter Spells** list you opened :
#
# ## **Levels 1–16**
# Every spell in these levels is **vendor‑bought** on Quarm.
#
# This includes:
# - **Charm** (12)
# - **Mesmerize** (4)
# - **Enthrall** (16)
# - **Breeze** (16)
# - **Root** (8)
# - **Tashan** (4)
# - **Animation pets** (1, 4, 8, 12, 16)
#
# On P99, some of these had awkward availability or required faction tricks.
# On Quarm, they’re simply sold.
#
# ---
#
# ## **Levels 19–29**
# Again, everything in this range is **vendor‑bought**, including:
#
# - **Tiny Companion** (19)
# - **Calm** (20)
# - **Tashani** (20)
# - **Beguile** (24)
# - **Alacrity** (24)
# - **Clarity** (29)
# - **Nullify Magic** (29)
# - **Uleen’s Animation** (29)
#
# On P99, **Clarity** and **Beguile** were research-only for a long time.
# On Quarm, they are **vendor spells**.
#
# ---
#
# # 🧪 So… What Enchanter Spells *Are* Research-Only on Quarm?
#
# Only **a few high-level spells** remain research-only or drop-only, and they’re all far above your current level.
#
# From your spell list , the ones that are *not* vendor spells include:
#
# ### **Research-only (Luclin/PoP era)**
# - **Dictate** (60) — charm up to 58
# - **Ancient: Eternal Rapture** (60)
# - **Ancient: Chaotic Visions** (60)
# - **Sleep** (63)
# - **Bliss** (64)
#
# ### **Drop-only**
# - **Koadic’s Endless Intellect** (60)
# - **Speed of the Brood** (60)
# - **Voice of Quellious** (65)
# - **Tranquility** (63)
#
# These are all raid-tier or high-end Luclin/PoP spells.
#
# ---
#
# # 🛒 Summary: What This Means for You Right Now
#
# ### ✔️ **You do NOT need to research anything from 1–29.**
# ### ✔️ **All your core charm, mez, haste, and clarity spells are vendor-bought.**
# ### ✔️ **Project Quarm is dramatically easier than P99 for spell acquisition.**
# ### ✔️ **Research only becomes relevant at level 60+.**
#
# You can safely level all the way through your 20s and 30s without touching a research component.
#
# ---
#
# # ⭐ If you want, I can also map out:
# - Where to buy each spell on Quarm (Highkeep, Erudin, Felwithe, etc.)
# - Which spells are worth prioritizing at 16
# - A full Enchanter spell progression roadmap for 1–60
#
# Just say the word and I’ll lay it out.
