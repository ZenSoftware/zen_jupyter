# %% [markdown]
# Absolutely — and since you opened the full **PQDI Mistmoore spawn list**, we can extract *actual mob levels* rather than relying on old P99-era approximations. Mistmoore is one of the most nonlinear zones in classic EQ, so breaking it down camp‑by‑camp is the only way to understand what’s safe for a **level 30 Enchanter**.
#
# Everything below is derived directly from the spawn data in your active tab .
#
# ---
#
# # 🏰 **Castle Mistmoore – Camp Level Breakdown (Project Quarm)**
# ### Based on actual NPC types and their known level ranges
#
# Mistmoore mobs fall into **four broad tiers**:
#
# | Tier | Mob Types | Approx Levels |
# |------|-----------|----------------|
# | **Tier 1** | Gargoyles, Gypsies | **22–28** |
# | **Tier 2** | Dark Offerer / Ritualist / Sacrificer / Harbinger / Herald / Usher | **28–33** |
# | **Tier 3** | Nobles, Advisors, Librarians, Dark Elf Nobles | **33–38** |
# | **Tier 4** | Ancille (basement), Werewolves, Black Dire, Glyphed mobs | **38–50+** |
#
# Now let’s map these to the *actual camps*.
#
# ---
#
# # 🌲 **1. Entrance / Graveyard (GY)**
# **Mob types:** Gargoyles, Gypsies, low-tier casters
# **Levels:** **22–28**
# **Notes:**
# - Safest area in the zone
# - Great for mid‑20s, but **too low for level 30** except as a warm‑up
# - Gargoyles are 100% charmable and easy to control
#
# **Verdict:** Below your level.
#
# ---
#
# # 🏚️ **2. Ramp / Pit / Pond Area**
# **Mob types:**
# - Dark Offerer
# - Dark Ritualist
# - Dark Sacrificer
# - Deathly Harbinger
# - Deathly Herald
# - Deathly Usher
# - Shadowy Scribe / Scrivener
# - Soul Seductress / Temptress
# - Thought Corruptor / Defiler / Spoiler
# - Will Pillager / Ravisher / Sapper
#
# **Levels:** **28–33**
# **Source:** These mobs appear repeatedly across the spawn list in your tab, all in the same level band.
#
# **Notes:**
# - This is the **sweet spot for level 30**
# - Tons of humanoid charm targets
# - Casters everywhere — expect stuns, charms, nukes
# - Social aggro is the main danger
#
# **Verdict:** **Ideal for level 30 Enchanter.**
#
# ---
#
# # 🏛️ **3. Castle Courtyard**
# **Mob types:** Same as Ramp/Pit, plus occasional nobles
# **Levels:** **29–35**
# **Notes:**
# - Slightly harder than the pit
# - More casters, more roamers
# - Still very doable at 30 with charm control
#
# **Verdict:** Good XP, moderate danger.
#
# ---
#
# # 🧛 **4. Castle Interior – First Floor**
# **Mob types:**
# - Dark Librarian
# - Dark Assistant Librarian
# - Advisor
# - Dark Elf Noble
# - Vampire Noble
# - Negotiator
# - Oracle
#
# **Levels:** **33–38**
# **Source:** These NPCs appear in the mid‑30s range in your spawn list.
#
# **Notes:**
# - Big jump in difficulty
# - High‑level casters
# - Many mobs have nasty spell sets
# - Rooms are tight and social aggro is brutal
#
# **Verdict:** **Too dangerous at 30 unless you’re duoing or extremely confident.**
#
# ---
#
# # 🩸 **5. Tower / Balcony / Upper Floors**
# **Mob types:**
# - Princess Cherista
# - Lasna Cheroon
# - Butler Syncall
# - Maid Issis
# - High‑tier casters
#
# **Levels:** **35–42**
# **Notes:**
# - Named mobs hit hard
# - High resist rates
# - Not suitable for 30
#
# **Verdict:** Avoid at your level.
#
# ---
#
# # 🧟 **6. Basement (Ancille / Vampiric Area)**
# **Mob types:**
# - Ghastish Ancille
# - Ghoulish Ancille
# - Spectral Ancille
# - Wraithish Ancille
# - Blood Wolves
# - Black Dire (level 40+)
#
# **Levels:** **38–50+**
# **Source:** Basement mobs consistently appear in the high 30s to 40s in your spawn list.
#
# **Notes:**
# - One of the deadliest areas in classic EQ
# - High‑level undead casters
# - Black Dire is a raid‑level mob for your level
#
# **Verdict:** **Absolutely not for level 30.**
#
# ---
#
# # 🧿 **7. Gypsy Camp (Inside Castle Grounds)**
# **Mob types:**
# - Gypsy Dancer
# - Gypsy Musician
# - Gypsy Ambassador
# - Werewolves
#
# **Levels:** **28–34**
# **Notes:**
# - Mixed difficulty
# - Some mobs are low 30s, some mid 30s
# - Werewolves hit hard but are charmable
#
# **Verdict:** Viable but spiky.
#
# ---
#
# # ⭐ **Summary: What’s Safe for Level 30?**
#
# ### **Best Zones for You Right Now**
# | Camp | Level Range | Safety | Notes |
# |------|-------------|--------|-------|
# | **Ramp / Pit / Pond** | **28–33** | ★★★★☆ | Best XP, best charm targets |
# | **Courtyard** | **29–35** | ★★★☆☆ | Harder but still good |
# | **Gypsy Camp** | **28–34** | ★★★☆☆ | Mixed difficulty |
#
# ### **Too Low**
# - Entrance
# - Graveyard
#
# ### **Too High**
# - Castle Interior
# - Balcony / Tower
# - Basement
#
# ---
#
# # 🧠 **Recommendation for You (Level 30 Enchanter)**
# Start at **Pit/Ramp**, charm a **Deathly Usher** or **Soul Seductress**, and work your way toward the Courtyard once you get comfortable with the spawn rhythm.
#
# If you want, I can map out **exact charm pet recommendations** based on the mob list you opened — some of these casters are absolute monsters when charmed.
