# %% [markdown]
# Absolutely — and nice job organizing those tabs into a “Leveling guides” group. I pulled in everything from your open pages, especially the **Per‑Level Hunting Guide** and the **Platinum Making Guide** (your tab with the big list of camps). Here’s a clean, Enchanter‑focused summary of **all viable level 30 options** based on what’s in those pages.
#
# ---
#
# # ⭐ **Level 30 Enchanter Leveling Options (Based on Your Open Guides)**
#
# ## 🏰 **1. Highkeep Guards (25–35)**
# **Source:** Platinum Making Guide
# - One of the strongest XP + plat camps in classic EQ.
# - Guards drop **Fine Steel Short Swords** (3.5–5p each) + 1–5p per kill.
# - Floors 1–2 are lower level; **floors 3–4 are perfect for level 30**.
# - There’s a **beta‑neutral vendor** (Tarn Visilin) you can sell to.
# - You can bank by using sneak/harmony/FD or by tanking the banker briefly.
# - **Charm is extremely strong here** — plenty of humanoid pets.
#
# **Downside:** Heavy Freeport faction hits.
#
# ---
#
# ## 🌲 **2. South Karana – Aviak Village (20–30+)**
# **Source:** Platinum Making Guide (Aviak note)
# - Egrets drop **1–5p each**, plus gems.
# - You can vendor to **Krak Windchaser** at the top of the tree.
# - Good charm pets (Aviak darters/warriors).
# - Wide open, safe, and easy to control.
#
# **Downside:** XP slows after 30, but still viable.
#
# ---
#
# ## 🧟 **3. Paineel Undead Guards (18–28+, but can push to low 30s)**
# **Source:** Platinum Making Guide
# - Undead guards drop **Bronze Bastard Swords** (~2.5p) and **Kite Shields** (~3.5p).
# - **No faction hits at all** — extremely rare for guard camps.
# - You can vendor and bank right inside Paineel if faction allows.
# - Some guards con blue into the early 30s.
#
# **Downside:** Starts to thin out at 30; better as a money camp than pure XP now.
#
# ---
#
# ## 🧝 **4. Highkeep Basement – Goblins (29–34)**
# **Source:** Per‑Level Hunting Guide (your tab includes this range)
# - Goblins are **perfect charm fodder** — casters, melee, lots of options.
# - Good XP, steady flow of **Left Goblin Ears** for the Captain Bosec quest.
# - Safe, indoor, consistent pulls.
#
# **Downside:** Can be contested.
#
# ---
#
# ## 🏝️ **5. Ocean of Tears – Gargoyles (22–28+, borderline for 30)**
# **Source:** Platinum Making Guide (Gargoyle section)
# - Technically below your level, but still blue at 30 on some spawns.
# - Gargoyle Eyes sell extremely well to players.
# - Easy charm kills.
#
# **Downside:** XP is slowing at 30; better for money than leveling now.
#
# ---
#
# ## 🐸 **6. Lake of Ill Omen – Sarnak Courier Circuit (20+)**
# **Source:** Platinum Making Guide (Gazughi Ring camp)
# - Not an XP hotspot, but if you want to **try for a Goblin Gazughi Ring**, this is the camp.
# - Respawns are fast, charmable mobs everywhere.
# - The ring is a game‑changer for Enchanters.
#
# **Downside:** Extremely rare drop; not efficient XP.
#
# ---
#
# ## 🧙 **7. Classic 30–34 Options from the Per‑Level Guide**
# **Source:** Per‑Level Hunting Guide (30–34 section)
# Your tab lists several general 30–34 zones, including:
#
# ### **– Mistmoore (Upper Floors / Graveyard)**
# - Great charm zone, humanoids everywhere.
# - Fast XP, but dangerous.
#
# ### **– Overthere (Frontier Mountains side)**
# - Wide open, easy charm kiting.
# - Lots of blue mobs at 30.
#
# ### **– Frontier Mountains (Goblins, Giants, Sarnaks)**
# - Tons of charmable mobs.
# - Safe, open, and steady XP.
#
# ### **– Sol A (Goblins)**
# - Tight corridors but excellent charm targets.
# - Good ZEM (zone XP modifier).
#
# ---
#
# # 🧠 **Best Picks for YOU (Level 30 Enchanter on Project Quarm)**
#
# ### **Top XP Choice:**
# **Highkeep Basement (Goblins)**
# - Perfect level range
# - Great charm targets
# - Quest turn‑ins for bonus XP
# - Safe and consistent
#
# ### **Top XP + Plat Choice:**
# **Highkeep Guards (Floors 3–4)**
# - Massive plat
# - Still great XP at 30
# - Indoor, predictable pulls
#
# ### **Low‑Stress Outdoor Option:**
# **South Karana Aviaks**
# - Easy charm
# - Good money
# - Relaxed, open zone
#
# ### **Risk/Reward Option:**
# **Mistmoore Upper Floors**
# - Fastest XP
# - Highest danger
#
# ---
#
# If you want, I can narrow this down even further based on your **gear**, **playstyle** (stationary vs. roaming), and whether you want **XP**, **plat**, or **both**.
