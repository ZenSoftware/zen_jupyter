# %% [markdown]
# Absolutely, Peter — and since you provided the full Level 8 spell block from the Enchanter wiki, I can break this down cleanly and give you a realistic **total cost estimate** for buying *every* level 8 spell on Project Quarm / P99‑style vendors.
#
# I’ll keep this tight, practical, and based on typical vendor prices for classic-era Enchanter spells.
#
# ---
#
# # 🧠 **Level 8 Enchanter Spells (from your HTML)**
# Here’s the list exactly as it appears:
#
# - **Alliance**
# - **Bind Sight**
# - **Cancel Magic**
# - **Chaotic Feedback**
# - **Enchant Clay**
# - **Enchant Silver**
# - **Eye of Confusion**
# - **Illusion: Gnome**
# - **Illusion: Wood Elf**
# - **Lesser Shielding**
# - **Mircyl's Animation** *(High Keep only)*
# - **Root**
# - **See Invisible**
# - **Sentinel**
# - **Soothe**
#
# That’s **15 spells total**.
#
# ---
#
# # 💰 **Typical Vendor Prices (Classic / P99 / Quarm‑style)**
# These are the standard price ranges for level 8 spells:
#
# ### **Common vendor spells (most of the list)**
# Usually **~9–12pp** each.
#
# ### **Illusions**
# Often **~8–10pp** each.
#
# ### **Tradeskill spells (Enchant Clay / Silver)**
# Usually **~12–15pp** each.
#
# ### **Mircyl’s Animation (High Keep)**
# Pet spells are always more expensive:
# Expect **~18–22pp**.
#
# ---
#
# # 📊 **Estimated Cost Per Spell**
# Here’s a clean breakdown using realistic vendor averages:
#
# | Spell | Est. Cost |
# |-------|-----------|
# | Alliance | 10pp |
# | Bind Sight | 10pp |
# | Cancel Magic | 12pp |
# | Chaotic Feedback | 12pp |
# | Enchant Clay | 14pp |
# | Enchant Silver | 14pp |
# | Eye of Confusion | 10pp |
# | Illusion: Gnome | 9pp |
# | Illusion: Wood Elf | 9pp |
# | Lesser Shielding | 10pp |
# | **Mircyl’s Animation** | **20pp** |
# | Root | 10pp |
# | See Invisible | 10pp |
# | Sentinel | 10pp |
# | Soothe | 10pp |
#
# ---
#
# # 🧮 **Total Estimated Cost**
# Let’s total it:
#
# - 13 normal spells × 10pp average = **130pp**
# - 2 tradeskill spells (14pp each) = **28pp**
# - Mircyl’s Animation = **20pp**
#
# ### ⭐ **Grand Total: ~178pp**
#
# ---
#
# # 🎉 **Your Level 8 Spell Budget Reality Check**
# You currently have **200pp**, which means:
#
# ### ✔️ You can afford **every single level 8 spell**
# ### ✔️ You will still have **~20pp left over**
# ### ✔️ You’re fully prepared for the NK → Nexus → Bazaar run
#
# This is *perfect* timing — you’ll hit level 8, buy your spells, and immediately be strong enough to handle the journey.
#
# ---
#
# If you want, I can also:
#
# - Prioritize which spells matter most for your run
# - Suggest which spells you can safely skip until later
# - Build a “Level 8 → 12 spell plan” so you’re ready for charm life
# - Help you budget for your **Level 12** spell explosion (Charm, Bind Affinity, etc.)
#
# Just say the word, Peter.
