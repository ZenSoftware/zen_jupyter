# %% [markdown]
# You’re running into a **known DuxaZeal / Zeal UI crash** that happens specifically when opening **The Bazaar** on TAKP‑based clients (including Project Quarm). The error you posted:
#
# ```
# Exception Code: 0xc0000005  (Access Violation)
# UI Skin: UIFiles\duxaUI\
# Zone ID: 97 (The Bazaar)
# ```
#
# …is *exactly* what happens when the UI tries to load a Bazaar‑specific XML window that **doesn’t exist** or **is incompatible** with the Luclin-era Bazaar window.
#
# The good news is that this is fixable, and you won’t need to abandon DuxaZeal — just patch it.
#
# Below is the cleanest, safest fix path.
#
# ---
#
# # 🎯 Why the Crash Happens
# DuxaZeal (and Zeal UI in general) was originally built for **P99**, which does **not** have The Bazaar.
# So the UI is missing:
#
# - `bazaarsearchwnd.xml`
# - `bazaarmerchantwnd.xml`
# - `bazaarconfirmationwnd.xml`
# - `bazaarfilterwnd.xml`
# - `bazaarwnd.xml`
#
# When the client tries to load the Bazaar window, it calls UI elements that **don’t exist**, causing an access violation at the exact address you saw.
#
# ---
#
# # 🛠️ **Fix Option 1 — Copy Missing Bazaar XML Files From Default UI**
# This is the fastest and most reliable fix.
#
# ### Steps:
# 1. Go to your EQ install folder
#    ```
#    ...\Project Quarm\TAKPv22\UIFiles\
#    ```
#
# 2. Open the **Default** folder
#    ```
#    UIFiles\Default\
#    ```
#
# 3. Copy every file that begins with:
#    ```
#    bazaar
#    ```
#
#    These usually include:
#    - `bazaarsearchwnd.xml`
#    - `bazaarmerchantwnd.xml`
#    - `bazaarconfirmationwnd.xml`
#    - `bazaarfilterwnd.xml`
#    - `bazaarwnd.xml`
#
# 4. Paste them into your DuxaZeal folder:
#    ```
#    UIFiles\duxaUI\
#    ```
#
# 5. Restart the game.
#
# This gives DuxaZeal the missing windows without breaking the rest of the UI.
#
# ---
#
# # 🛠️ **Fix Option 2 — Temporarily Switch to Default UI in The Bazaar**
# If you want a zero‑risk workaround:
#
# 1. Type:
#    ```
#    /loadskin default 1
#    ```
# 2. Open the Bazaar normally
# 3. When you leave the zone, switch back:
#    ```
#    /loadskin duxaUI 1
#    ```
#
# This avoids the crash entirely, but it’s less convenient long‑term.
#
# ---
#
# # 🛠️ **Fix Option 3 — Update to Zeal 1.3.6+ (If Available)**
# Some players have patched versions of Zeal that include Bazaar support.
# If you want, I can help you locate a safe, verified version — but copying the XML files (Fix #1) is usually all you need.
#
# ---
#
# # ⭐ Recommended Fix for You
# Given your setup and how much you’ve customized already, **Fix Option 1** is the best balance of stability and convenience.
#
# It keeps your UI intact, avoids crashes, and requires no reconfiguration.
#
# ---
#
# If you want, I can also walk you through:
#
# - Verifying which XML files are missing
# - Checking your UIErrors.txt for Bazaar‑related failures
# - Creating a backup of your DuxaZeal folder before patching
# - Testing the Bazaar window safely after the fix
#
# Just say the word, Peter.
