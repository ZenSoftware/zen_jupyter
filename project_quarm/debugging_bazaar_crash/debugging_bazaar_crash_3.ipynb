# %% [markdown]
# ```
# Bazaar Trader Mode is now *OFF*
# ```

# %% [markdown]
# Here is a list of all files that contain the keyword bazaar in my TAKPv22 installation folder:
# ```
# TAKPv22\bazaar.emt
# TAKPv22\bazaar.mp3
# TAKPv22\bzrlog_ctq_Zenmez.txt
# TAKPv22\dbg.txt
# TAKPv22\eqgame.exe
# TAKPv22\eqlog_Zenmez_pq.proj.txt
# TAKPv22\eqmac.exe
# TAKPv22\eqstr_en.txt
# TAKPv22\UIErrors.txt
# TAKPv22\UI_Zenmez_pq.proj.ini
# TAKPv22\Zeal.asi
# TAKPv22\Zeal.pdb
# TAKPv22\uifiles\default\defaults.ini
# TAKPv22\uifiles\default\EQUI.xml
# TAKPv22\uifiles\default\EQUI_BazaarSearchWnd.xml
# TAKPv22\uifiles\default\EQUI_BazaarWnd.xml
# TAKPv22\uifiles\default\EQUI_Beta.xml
# TAKPv22\uifiles\duxaUI\EQUI_FeedbackWnd.xml
# TAKPv22\uifiles\DuxaZeal\EQUI_FeedbackWnd.xml
# TAKPv22\uifiles\Infiniti-Blue\EQUI_BazaarSearchWnd.xml
# TAKPv22\uifiles\Nemesis\EQUI_FeedbackWnd.xml
# TAKPv22\uifiles\Nemesis\succor.txt
# TAKPv22\uifiles\poweroftwo\EQUI.xml
# TAKPv22\uifiles\poweroftwo\EQUI_BazaarSearchWnd.xml
# TAKPv22\uifiles\poweroftwo\EQUI_BazaarWnd.xml
# TAKPv22\uifiles\poweroftwo\optional files\zone finder\zonefinder_full\EQUI_FeedbackWnd.xml
# TAKPv22\uifiles\QQ\EQUI_BazaarSearchWnd.xml
# TAKPv22\uifiles\QQ\EQUI_BazaarWnd.xml
# TAKPv22\uifiles\QQ\EQUI_FeedbackWnd.xml
# TAKPv22\uifiles\QQ\succor.txt
# TAKPv22\uifiles\vert\EQUI_BazaarSearchWnd.xml
# TAKPv22\uifiles\vert\EQUI_BazaarWnd.xml
# TAKPv22\uifiles\WizModRyo\EQUI.xml
# TAKPv22\uifiles\WizModRyo\EQUI_BazaarSearchWnd.xml
# TAKPv22\uifiles\WizModRyo\EQUI_BazaarWnd.xml
# ```
#
# Am I missing anything?

# %% [markdown]
# spoke to `saussage`.  Confirmed that his bazaar feature is working.

# %% [markdown]
# eqemupatcher.exe log:
# ```
# Patching with patcher version 1.0.6.4...
# Self update needed, starting with self patch...
# Self update of 545.5 KB will be used next run
# Resuming patching...
# RaceData.txt (802 bytes)
# ZoneData.txt (40 bytes)
# dpvs.dll (156.5 KB)
# eqgame.dll (303.5 KB)
# quarmclient.ini (170 bytes)
# spells_en.txt (1.82 MB)
# uifiles\default\EQUI.xml (3.84 KB)
# uifiles\default\EQUI_BankGridWnd.xml (161.34 KB)
# uifiles\default\EQUI_BankWnd.xml (22.94 KB)
# uifiles\default\EQUI_ShortDurationBuffWindow.xml (4.89 KB)
# uifiles\duxaUI\EQUI_BankGridWnd.xml (162.62 KB)
# uifiles\duxaUI\EQUI_BankWnd.xml (24.99 KB)
# uifiles\duxaUI\EQUI_ShortDurationBuffWindow.xml (12.24 KB)
# veksar_chr.s3d (4.9 MB)
# Complete! Patched 7.56 MB in 02.80 seconds. Press Play to begin.
# ```
