# %% [markdown]
# # 🔧 Zeal Settings That Improve Sharpness
#
# ## 🎯 **1. Increase Internal Rendering Resolution**
# Zeal lets you render the game at a higher internal resolution than your window, which produces a crisp, anti‑aliased look.
#
# ### Go to:
# **Options → Zeal → Graphics**
#
# ### Adjust:
# - **Render Scale:**
#   - Set to **1.25×** or **1.5×** for a noticeable clarity boost
#   - Set to **2×** if your GPU can handle it (big jump in sharpness)
#
# This is the single most impactful setting.
#
# ---
#
# ## 🎨 **2. Enable Zeal’s Enhanced Texture Filtering**
# The original client uses very basic bilinear filtering. Zeal upgrades this.
#
# ### Options → Zeal → Graphics
# - **Texture Filtering:** set to **Anisotropic 16×**
# - **Mipmap Bias:** set to **-1.0** (sharper textures at distance)
#
# This makes ground textures, walls, and armor patterns much clearer.
#
# ---
#
# ## 🖼️ **3. Improve UI and Font Rendering**
# Zeal’s font engine is vastly better than the original.
#
# ### Options → Zeal → Nameplate / Text
# - **Font:** choose a high‑quality `.spritefont` (you already know where to place them)
# - **Font Size:** increase by 1–2 points for crispness
# - **Outline Thickness:** set to **1**
# - **Shadow:** set to **0** (shadows blur text)
#
# ### Options → Zeal → UI
# - **UI Scaling:** set to **1.0** (avoid fractional scaling, which blurs UI textures)
#
# ---
#
# ## 🌫️ **4. Disable Blur‑Inducing Legacy Effects**
# The 2002 client uses some “softening” effects that look muddy on modern monitors.
#
# ### In `eqclient.ini`:
# ```
# MipMapping=FALSE
# TextureQuality=1
# UseLitBatches=TRUE
# ```
#
# ### In-game:
# - Turn **off** “Advanced Lighting”
# - Turn **off** “Dynamic Lighting”
# - Turn **off** “Sky Cubemap” (Luclin skybox is low-res)
#
# These reduce blur and shimmering.
#
# ---
#
# ## 🖥️ **5. Use dgVoodoo2 for Sharper Output**
# You already have dgVoodoo2 installed, so tune it for clarity.
#
# ### In dgVoodooCpl:
# - **Antialiasing:** 4× or 8×
# - **Texture Filtering:** Force **Anisotropic 16×**
# - **Resolution:** “Unforced” (let Zeal handle scaling)
# - **VRAM:** Max it out
# - **Disable watermark:** On
#
# dgVoodoo2 + Zeal’s render scaling = the cleanest possible output.
#
# ---
#
# # 🧪 Recommended “Sharpness Preset”
# If you want a quick, reliable setup:
#
# ### Zeal:
# - Render Scale: **1.5×**
# - Texture Filtering: **Anisotropic 16×**
# - Mipmap Bias: **-1.0**
# - UI Scale: **1.0**
# - High‑quality spritefont selected
#
# ### dgVoodoo2:
# - Antialiasing: **4×**
# - Texture Filtering: **16×**
# - VRAM: **Max**
#
# This combination gives a crisp, modern look while keeping the classic feel.
#
# ---
#
# # If you want, I can help you:
# - Pick the best spritefont for your UI
# - Tune settings for your specific GPU
# - Compare screenshots and optimize further
# - Build a “performance mode” vs “quality mode” profile
#
# Just tell me what kind of look you’re aiming for — ultra crisp, classic but clean, or something in between.
