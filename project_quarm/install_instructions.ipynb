# %% [markdown]
# # Install Resources
# - [Project Quarm - Install Guides](https://quarm.guide/install-guides)
# - [Zeal GitHub](https://github.com/CoastalRedwood/Zeal/releases)
# - [eqgame.dll GitHub](https://github.com/CoastalRedwood/akplus-dll/releases)
# - [eqw.dll GitHub](https://github.com/CoastalRedwood/eqw_takp/releases)
# - [DuxaZeal download link](https://www.eqinterface.com/downloads/fileinfo.php?id=6973)
# - [Project Quarm - Discord - #server-files](https://discord.gg/projectquarm): Do not run `eqemupatcher.exe`.  Just unzip `QuarmPatcher.zip` into the root of the `TAKPv22` directory.
