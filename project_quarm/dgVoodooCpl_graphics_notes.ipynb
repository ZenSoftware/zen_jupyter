# %% [markdown]
# Absolutely, Peter — and this is right in your wheelhouse. Since you’re already deep into Zeal, dgVoodoo2, and visual optimization, here’s a clean, practical walkthrough that gets you *exactly* those settings without any guesswork.
#
# ---
#
# ## 🎨 dgVoodooCpl Setup for Project Quarm (Zeal Client)
#
# These steps assume you’re using **dgVoodoo2 v2.8+** and have the **dgVoodooCpl.exe** in the same folder as your EQ client (or pointed at it via the config path).
#
# ---
#
# ## 🖥️ 1. Open dgVoodooCpl
# - Run **dgVoodooCpl.exe**
# - Make sure the **Config Folder / Running Instance** is pointed at your **Project Quarm / Zeal** directory so the settings apply to the right client.
#
# ---
#
# ## ✨ 2. Go to the **DirectX** tab
# This is where all the important rendering overrides live.
#
# ### **Antialiasing**
# - Find **Antialiasing (MSAA)**
# - Set it to **4×** or **8×**
#   - 4× = great balance
#   - 8× = slightly sharper edges, slightly heavier GPU load
# - EQ is ancient, so even 8× barely dents modern hardware.
#
# ---
#
# ### **Texture Filtering**
# - Find **Force anisotropic filtering**
# - Set it to **16×**
#   - This dramatically sharpens ground textures, walls, and long-distance surfaces
#   - EQ benefits *massively* from this because the original mipmaps are low-res
#
# ---
#
# ### **Resolution**
# - Find **Resolution** dropdown
# - Set it to **Unforced**
#   - This is important:
#     - **Zeal handles scaling internally**, and forcing a resolution in dgVoodoo can cause UI stretching or blur
#   - Unforced = cleanest results with Zeal’s renderer
#
# ---
#
# ### **VRAM**
# - Find **VRAM** slider
# - Set it to the **maximum value**
#   - dgVoodoo uses this as a virtual cap
#   - Maxing it prevents texture thrashing and improves stability with high-res icon packs or UI mods
#
# ---
#
# ### **dgVoodoo Watermark**
# - Find **dgVoodoo watermark**
# - Set it to **Off**
#   - Removes the red watermark in the corner
#   - Makes screenshots and gameplay cleaner
#
# ---
#
# ## 💾 3. Apply & Save
# - Click **Apply**
# - Then click **OK**
# - dgVoodoo writes a **dgVoodoo.conf** file into your Zeal folder
#
# ---
#
# ## 🔍 4. Quick Verification
# When you launch Project Quarm:
# - Edges should look smoother (AA)
# - Distant terrain should be crisp (AF 16×)
# - No dgVoodoo watermark
# - No scaling artifacts (Zeal handles it)
#
# If you want, I can also help you:
# - Tune Zeal’s internal renderer
# - Pair this with dgVoodoo’s mipmapping options
# - Optimize gamma/brightness for classic EQ lighting
# - Compare dgVoodoo vs. pure Zeal rendering paths
#
# Just say the word — you’re already building a gorgeous setup.
