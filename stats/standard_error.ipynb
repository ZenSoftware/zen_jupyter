# %% [markdown]
# **The standard error is a measure of how much a sample statistic (like a mean or proportion) would vary if you repeated the sampling many times.** It tells you how *precise* your estimate is: smaller SE → more precise estimate. This definition is consistent across the sources retrieved.
#
# ---
#
# ## 📘 What “Standard Error” Really Means
# - It is the **standard deviation of a sampling distribution**—usually the sampling distribution of the mean.
# - It reflects **uncertainty**: how much your sample mean might differ from the true population mean.
# - It decreases as sample size increases (because larger samples give more stable estimates).
#
# ---
#
# ## 🔢 Formula
# For a sample mean:
#
# $$
# SE = \frac{s}{\sqrt{n}}
# $$
#
# Where:
# - $s$ = sample standard deviation
# - $n$ = sample size
#
# ---
#
# ## 📊 Quick Example
# If your sample has:
# - Standard deviation $s = 7.07$
# - Sample size $n = 5$
#
# Then:
#
# $$
# SE = \frac{7.07}{\sqrt{5}} \approx 3.16
# $$
#
# This means your sample mean is expected to vary by about **±3.16** from sample to sample.
#
# ---
#
# ## 🧠 Why It Matters
# - Used to build **confidence intervals**
# - Helps judge **reliability** of estimates
# - Essential for **hypothesis testing**
# - Smaller SE → more confidence in your sample statistic
