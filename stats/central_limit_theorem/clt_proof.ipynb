# %% [markdown]
# ## 🎯 Summary of *“Proof of the Central Limit Theorem”* (Steve Brunton)
#
#
# ![Proof of CLT](../../images/proof_of_clt.png)
#
# [🎞️Steve Brunton: Proof of the Central Limit Theorem](https://www.youtube.com/watch?v=nWadI0_u6QU&list=PLMrJAkhIeNNR3sNYvfgiKgcStwuPSts9V&index=44)
#
# The video presents an intuitive, structured walkthrough of **why the Central Limit Theorem (CLT) is true**, focusing on the underlying mechanics rather than a purely formal proof.
#
# ### 🧩 Core Ideas Covered
# - **Goal of the CLT:** Show that the sum (or average) of many independent, identically distributed random variables tends toward a **normal distribution**, regardless of the original distribution (as long as variance is finite).
# - **Key Strategy:**
#   The proof uses **moment generating functions (MGFs)** or **characteristic functions** to track how distributions behave when summed.
# - **MGF Factorization:**
#   Because independent variables have MGFs that multiply, the MGF of the normalized sum can be expanded using Taylor series.
# - **Normalization:**
#   By centering and scaling the sum appropriately, higher‑order terms vanish as $n \to \infty$, leaving the MGF of a standard normal distribution.
# - **Conclusion:**
#   Since MGFs uniquely determine distributions, the limiting distribution must be **Gaussian**.
#
# ### 🧠 Intuition Emphasized
# - Repeated addition “smooths out” irregularities in the original distribution.
# - The Gaussian emerges as the *universal attractor* for sums of independent noise sources.
# - The proof highlights how the second moment (variance) dominates the limiting behavior.
#
# ### 📌 What You’d Take Away
# - A conceptual and semi‑rigorous proof of the CLT.
# - A deeper appreciation for why the normal distribution appears everywhere.
# - A sense of how MGFs provide a powerful lens for understanding convergence.

# %% [markdown]
# ---
#
# # 🌟 Why divide by $ \sigma \sqrt{n} $ when normalizing the sum?
#
# Suppose you have i.i.d. random variables:
#
# $$
# X_1, X_2, \dots, X_n
# $$
#
# each with:
#
# - mean $ \mu $
# - variance $ \sigma^2 $
#
# Define the **sum**:
#
# $$
# S_n = X_1 + X_2 + \cdots + X_n
# $$
#
# Now look at its variance.
#
# ---
#
# # 📌 Step 1: Variance of the sum
#
# Because the variables are independent:
#
# $$
# \mathrm{Var}(S_n) = \mathrm{Var}(X_1) + \cdots + \mathrm{Var}(X_n)
# = n \sigma^2
# $$
#
# So the **standard deviation** of the sum is:
#
# $$
# \sqrt{\mathrm{Var}(S_n)} = \sigma \sqrt{n}
# $$
#
# This is the key fact.
#
# ---
#
# # 📌 Step 2: What does “normalize” mean?
#
# To normalize a random variable so that it has:
#
# - mean $0$
# - standard deviation $1$
#
# you subtract its mean and divide by its standard deviation.
#
# For the sum $S_n$:
#
# - mean is $n\mu$
# - standard deviation is $ \sigma \sqrt{n} $
#
# So the normalized version is:
#
# $$
# \frac{S_n - n\mu}{\sigma \sqrt{n}}
# $$
#
# This is exactly the expression that appears in the CLT.
#
# ---
#
# # 📌 Step 3: Why this scaling specifically?
#
# Because the CLT is about the **shape** of the distribution of the sum as $n$ grows.
#
# If you didn’t divide by $ \sigma \sqrt{n} $:
#
# - the variance would blow up like $n$
# - the distribution would spread wider and wider
# - you’d never get a stable limiting distribution
#
# Dividing by $ \sigma \sqrt{n} $ rescales the sum so that its variance becomes:
#
# $$
# \mathrm{Var}\!\left( \frac{S_n}{\sigma \sqrt{n}} \right)
# = \frac{n\sigma^2}{\sigma^2 n}
# = 1
# $$
#
# This keeps the distribution at a fixed “width,” allowing it to converge to the standard normal.
#
# ---
#
# # 🎯 Intuition in one sentence
#
# **The sum gets $n$ times more variable, so you need to divide by $ \sqrt{n} $ to keep the variability constant.**
#
# The extra $ \sigma $ just adjusts for the scale of the original variables.

# %% [markdown]
# ---
#
# # Showing how $m'(0) = \mathbb{E}[X]$
#
# We start with the **moment generating function** of a random variable $X$:
# $$
# m(t) = \mathbb{E}\big[e^{tX}\big].
# $$
#
# Differentiate with respect to $t$:
# $$
# m'(t) = \frac{d}{dt}\mathbb{E}\big[e^{tX}\big] = \mathbb{E}\big[X e^{tX}\big],
# $$
# where we’ve moved the derivative inside the expectation (this is standard under mild regularity conditions).
#
# Now evaluate at $t = 0$:
# $$
# m'(0) = \mathbb{E}\big[X e^{0\cdot X}\big] = \mathbb{E}[X \cdot 1] = \mathbb{E}[X].
# $$
#
# So in general,
# $$
# m'(0) = \mathbb{E}[X],
# $$
# i.e., **the first derivative of the MGF at 0 is the mean** of $X$.
#
# In Steve’s setup, the random variables are assumed to have **mean 0**, so
# $$
# \mathbb{E}[X] = 0 \quad \Rightarrow \quad m'(0) = 0.
# $$
#
# Then in the Taylor expansion
# $$
# m(t) = m(0) + t\,m'(0) + \frac{t^2}{2}m''(0) + \cdots,
# $$
# the linear term becomes
# $$
# t\,m'(0) = t \cdot 0 = 0,
# $$
# which is why he can drop it.

# %% [markdown]
# ---
#
# # 🎯 Show how $\frac{t^2}{2}\, m''(0) \;=\; \frac{t^2 \sigma^2}{2}$
# Show that
# $$
# \frac{t^2}{2}\, m''(0) \;=\; \frac{t^2 \sigma^2}{2}.
# $$
#
# So we need to understand **what $m''(0)$ equals**.
#
# ---
#
# # 🔍 Step 1 — Start from the definition of the MGF
# For a random variable $X$, the moment generating function is
# $$
# m(t) = \mathbb{E}[e^{tX}].
# $$
#
# ---
#
# # 🔍 Step 2 — Differentiate twice
# First derivative:
# $$
# m'(t) = \mathbb{E}[X e^{tX}].
# $$
#
# Second derivative:
# $$
# m''(t) = \mathbb{E}[X^2 e^{tX}].
# $$
#
# This comes from differentiating inside the expectation again.
#
# ---
#
# # 🔍 Step 3 — Evaluate at $t = 0$
# Plugging in $t = 0$:
#
# $$
# m''(0) = \mathbb{E}[X^2 e^{0\cdot X}]
#        = \mathbb{E}[X^2].
# $$
#
# And of course:
#
# $$
# \mathbb{E}[X^2] = \operatorname{Var}(X) + (\mathbb{E}[X])^2.
# $$
#
# But in Steve’s setup, the mean is **0**, so:
#
# $$
# \mathbb{E}[X^2] = \operatorname{Var}(X) = \sigma^2.
# $$
#
# Thus:
#
# $$
# m''(0) = \sigma^2.
# $$
#
# ---
#
# # 🎉 Final Step — Plug into the Taylor term
# The second‑order Taylor term is:
#
# $$
# \frac{t^2}{2} m''(0)
#   = \frac{t^2}{2} \sigma^2.
# $$

# %% [markdown]
# ---
#
# # 🌱 What Steve Is Doing in the Taylor Expansion
#
# He expands the MGF $m(t)$ around $t = 0$:
#
# $$
# m(t) = m(0) + t m'(0) + \frac{t^2}{2} m''(0) + \text{higher‑order terms}.
# $$
#
# Since
# - $m(0) = 1$,
# - $m'(0) = 0$ (mean is zero),
# - $m''(0) = \sigma^2$,
#
# the expansion becomes:
#
# $$
# m(t) = 1 + \frac{t^2 \sigma^2}{2} + \text{(third‑order and higher terms)}.
# $$
#
# Now the question is: **what happens to those third‑order and higher terms?**
#
# ---
#
# # 🌿 What “little‑o” Means
#
# The notation
# $$
# o(t^2)
# $$
# means:
#
# > A function that becomes *negligible compared to $t^2$* as $t \to 0$.
#
# Formally:
# $$
# \lim_{t \to 0} \frac{o(t^2)}{t^2} = 0.
# $$
#
# So if you divide the remainder by $t^2$, it goes to zero.
#
# This is stronger than just saying “small” — it says “*vanishes faster than $t^2$*.”
#
# ---
#
# # 🌳 Why the Third‑Order Term Becomes $o(t^2)$
#
# The next term in the Taylor expansion is:
#
# $$
# \frac{t^3}{6} m^{(3)}(\xi)
# $$
#
# for some $\xi$ between $0$ and $t$ (this is the Lagrange form of the remainder).
#
# Now look at how it behaves relative to $t^2$:
#
# $$
# \frac{\frac{t^3}{6} m^{(3)}(\xi)}{t^2}
# = \frac{t}{6} m^{(3)}(\xi).
# $$
#
# As $t \to 0$,
# - $t \to 0$,
# - $m^{(3)}(\xi)$ stays finite (MGFs are smooth near 0).
#
# So the whole expression goes to **0**.
#
# That is exactly the definition of:
#
# $$
# \frac{t^3}{6} m^{(3)}(\xi) = o(t^2).
# $$
#
# And the same logic applies to all higher‑order terms (they vanish even faster).
#
# ---
#
# # 🌟 Putting It All Together
#
# So the MGF expansion becomes:
#
# $$
# m(t) = 1 + \frac{t^2 \sigma^2}{2} + o(t^2).
# $$
#
# This is the compact way of saying:
#
# > “Everything beyond the quadratic term becomes negligible compared to $t^2$ as $t \to 0$.”
#
# This is exactly what Steve uses when he plugs in
# $$
# t = \frac{s}{\sigma\sqrt{n}}
# $$
# and lets $n \to \infty$.
# The little‑o term shrinks away, leaving only the Gaussian MGF.

# %% [markdown]
# ---
#
# # 🌱 What “little‑o” Formally Means
#
# The whole point of *little‑o* notation is to **compare the size of two functions**, and the way we compare them is by dividing one by the other.
#
# Saying
# $$
# r(t) = o(t^2) \quad \text{as } t \to 0
# $$
# means:
#
# $$
# \lim_{t\to 0} \frac{r(t)}{t^2} = 0.
# $$
#
# So the ratio goes to zero.
#
# But why *this* ratio?
#
# Because little‑o is all about **relative size**.
#
# ---
#
# # 🌿 Why We Divide by $t^2$
#
# Think of it like comparing two runners:
#
# - Runner A: speed = $t^2$
# - Runner B: speed = $r(t)$
#
# To see whether B is “negligible compared to” A, you look at:
#
# $$
# \frac{\text{speed of B}}{\text{speed of A}}.
# $$
#
# If this ratio → 0, then B is falling behind so fast that A completely dominates.
#
# That’s exactly what’s happening with functions.
#
# ---
#
# # 🌳 A Concrete Example
#
# Suppose
# $$
# r(t) = t^3.
# $$
#
# Then:
#
# $$
# \frac{r(t)}{t^2} = \frac{t^3}{t^2} = t.
# $$
#
# As $t \to 0$, this goes to 0.
#
# So $t^3$ is *little‑o* of $t^2$:
#
# $$
# t^3 = o(t^2).
# $$
#
# This matches intuition: $t^3$ shrinks faster than $t^2$.
#
# ---
#
# # 🌲 What If We Divided by Something Else?
#
# If you divided by $t^3$ instead:
#
# $$
# \frac{t^3}{t^3} = 1,
# $$
#
# which does **not** go to zero.
# So relative to $t^3$, the function is *not* negligible.
#
# If you divided by $t$:
#
# $$
# \frac{t^3}{t} = t^2,
# $$
#
# which *does* go to zero — meaning $t^3$ is also negligible compared to $t$.
#
# So the denominator you choose determines **what you’re comparing against**.
#
# ---
#
# # 🌟 Why $t^2$ Specifically in the CLT Proof?
#
# Because the Taylor expansion of the MGF is:
#
# $$
# m(t) = 1 + 0\cdot t + \frac{\sigma^2}{2} t^2 + \text{higher‑order terms}.
# $$
#
# The quadratic term is the **last one we keep**.
#
# Everything beyond it must be shown to be “negligible compared to $t^2$.”
#
# So we check:
#
# $$
# \frac{\text{remainder}}{t^2} \to 0.
# $$
#
# This is exactly the definition of:
#
# $$
# \text{remainder} = o(t^2).
# $$
#
# ---
#
# # 🌈 Intuition in One Sentence
#
# We divide by $t^2$ because we want to know:
#
# > “Does the remainder shrink *faster* than the $t^2$ term we’re keeping?”
#
# If yes, then it’s negligible — and little‑o notation captures that idea perfectly.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 1, 1000)
plt.plot(x, x**2, color="C0", label="$x^2$")
plt.plot(x, x**3, color="C1", label="$x^3$")
plt.plot(x, x**4, color="C2", label="$x^4$")
plt.plot(x, x**5, color="C3", label="$x^5$")
plt.title("Showing how larger powers of x go to zero faster")
plt.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# # 🎯 **1. Why does the MGF Taylor expansion use the limit as $t \to 0$?**
#
# Yes — the reason is **precisely** that *all moments of a random variable are encoded in the derivatives of the MGF at $t = 0$*.
#
# The MGF is
# $$
# m(t) = \mathbb{E}[e^{tX}].
# $$
#
# Its derivatives at 0 give the moments:
#
# - $m(0) = 1$
# - $m'(0) = \mathbb{E}[X]$
# - $m''(0) = \mathbb{E}[X^2]$
# - $m^{(k)}(0) = \mathbb{E}[X^k]$
#
# So if you want to approximate the MGF using its moments, you *must* expand around $t = 0$. That’s the only point where the derivatives correspond directly to the moments.
#
# This is why the Taylor expansion is taken as $t \to 0$, and why the remainder is expressed as $o(t^2)$ *as $t \to 0$*.
#
# ---
#
# # 🌱 **2. Is little‑o defined only for limits approaching 0?**
#
# Not at all — little‑o works for **any limit point**.
#
# The general definition is:
#
# $$
# f(x) = o(g(x)) \quad \text{as } x \to a
# $$
#
# means
#
# $$
# \lim_{x \to a} \frac{f(x)}{g(x)} = 0.
# $$
#
# So you can have:
#
# - $f(x) = o(g(x))$ as $x \to 0$
# - $f(x) = o(g(x))$ as $x \to \infty$
# - $f(x) = o(g(x))$ as $x \to 5$
# - $f(t) = o(g(t))$ as $t \to t_0$
#
# It’s completely general.
#
# ---
#
# # 🌿 **3. So why does the CLT proof specifically use little‑o as $t \to 0$?**
#
# Because the Taylor expansion of the MGF is only valid *near* $t = 0$, and the coefficients of the expansion are the moments evaluated at 0.
#
# The CLT proof uses:
#
# $$
# m(t) = 1 + \frac{\sigma^2}{2} t^2 + o(t^2) \quad \text{as } t \to 0.
# $$
#
# Then it substitutes:
#
# $$
# t = \frac{s}{\sigma\sqrt{n}}.
# $$
#
# As $n \to \infty$, this substituted $t$ automatically goes to 0, which is exactly the regime where the Taylor expansion is valid.
#
# So the whole proof hinges on:
#
# - expanding the MGF around 0,
# - showing the remainder is negligible compared to $t^2$,
# - then letting $t$ shrink to 0 via the normalization.
#
# ---
#
# # 🌟 **4. Intuition in one sentence**
#
# We expand the MGF at $t=0$ because that’s where the moments live, and little‑o can be used at any limit point — but in the CLT proof, the relevant limit is $t \to 0$ because the normalization forces it.
