# %% [markdown]
# ---
#
# # 📘 Practice Problems Using the Gamma CDF
#
# ## 🔹 **1. Basic Probability Using the Gamma CDF**
# Let $X \sim \text{Gamma}(k=3, \theta=2)$.
# Compute:
#
# 1. $P(X \le 4)$
# 2. $P(2 < X < 6)$
# 3. $P(X > 10)$
#
# All of these require evaluating the Gamma CDF $F_X(x)$.
#
# ---
#
# ## 🔹 **2. Using the Gamma CDF to Find a Quantile**
# Let $X \sim \text{Gamma}(k=5, \theta=1)$.
# Find the value $x$ such that:
#
# $$
# P(X \le x) = 0.90
# $$
#
# (This is the 90th percentile, so you’ll need the inverse CDF.)
#
# ---
#
# ## 🔹 **3. Waiting-Time Interpretation**
# A call center receives calls according to a Poisson process with rate $\lambda = 12$ per hour.
# Let $T_4$ be the waiting time until the 4th call.
#
# Since $T_4 \sim \text{Gamma}(k=4, \theta = 1/12)$, compute:
#
# 1. $P(T_4 \le 10 \text{ minutes})$
# 2. $P(T_4 > 20 \text{ minutes})$
#
# ---
#
# ## 🔹 **4. Reliability / Failure-Time Problem**
# A machine has a lifetime modeled as $X \sim \text{Gamma}(k=2, \theta=500)$ hours.
#
# 1. What is the probability the machine lasts **at least** 1000 hours?
# 2. What is the probability it fails **before** 300 hours?
# 3. Find the median lifetime.
#
# ---
#
# ## 🔹 **5. Sum of Exponentials**
# Suppose $X_1, X_2, X_3$ are independent exponential random variables with rate $\lambda = 0.5$.
# Let $S = X_1 + X_2 + X_3$.
#
# Since $S \sim \text{Gamma}(k=3, \theta = 1/0.5 = 2)$, compute:
#
# 1. $P(S < 5)$
# 2. $P(3 < S < 10)$
#
# ---
#
# ## 🔹 **6. Hypothesis Testing With a Gamma CDF**
# A scientist measures the total radiation emitted in a fixed time window.
# Under normal conditions, the total radiation $X$ follows a Gamma distribution with $k=8$, $\theta=0.5$.
#
# They observe $X = 7.2$.
# Compute the **p‑value** for testing:
#
# $$
# H_0: \text{system is normal} \quad \text{vs.} \quad H_1: \text{radiation is unusually high}
# $$
#
# So you need:
#
# $$
# p = P(X \ge 7.2 \mid H_0)
# $$
#
# ---
#
# ## 🔹 **7. Bayesian Posterior Probability**
# A prior for a Poisson rate parameter $\lambda$ is $\text{Gamma}(k=2, \theta=1)$.
# After observing data, the posterior becomes $\text{Gamma}(k=7, \theta=1/3)$.
#
# Compute:
#
# 1. $P(\lambda \le 2)$
# 2. $P(\lambda \ge 5)$
#
# Both require the Gamma CDF.
#
# ---
#
# ## 🔹 **8. Confidence Interval Using the Gamma CDF**
# Let $X_1, \dots, X_n$ be i.i.d. exponential with rate $\lambda$.
# Then $S = \sum X_i \sim \text{Gamma}(n, 1/\lambda)$.
#
# For $n = 10$, $S = 18.4$, construct a **95% confidence interval** for $\lambda$ using the Gamma CDF.
#
# ---
#
# ## 🔹 **9. Transformations**
# Let $X \sim \text{Gamma}(k=4, \theta=3)$.
# Define $Y = X/2$.
#
# Compute:
#
# 1. $P(Y \le 5)$
# 2. $P(Y > 10)$
#
# Use the fact that:
#
# $$
# P(Y \le y) = P(X \le 2y)
# $$
#
# ---
#
# ## 🔹 **10. Mixture Problem**
# A system has two modes:
#
# - Mode A: $X \sim \text{Gamma}(k=2, \theta=4)$ with probability 0.7
# - Mode B: $X \sim \text{Gamma}(k=5, \theta=1)$ with probability 0.3
#
# Compute:
#
# $$
# P(X \le 6)
# $$
#
# This requires combining two Gamma CDFs.
#
# ---
#
# # Want solutions, hints, or a step‑by‑step walkthrough?
# I can guide you through any of these — or generate more at different difficulty levels.
