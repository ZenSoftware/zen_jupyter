# %% [markdown]
# # 🔍 Clarifying p-values vs surival functions
# **A p‑value is *not* the same thing as a survival function**, but in many hypothesis‑testing situations, a p‑value *is computed using* a survival function (or its two‑tailed variant).
#
# ---
#
# # 📘 **What each term actually means**
#
# ## 📌 **Survival function**
# For a random variable $X$, the survival function is:
#
# $$
# S(x) = P(X \ge x)
# $$
#
# It’s simply the probability of being in the *upper tail* beyond $x$.
# It’s a property of the **distribution**, not of a hypothesis test.
#
# ---
#
# ## 📌 **p‑value**
# A p‑value is:
#
# $$
# \text{p-value} = P(\text{test statistic is as extreme or more extreme than observed} \mid H_0)
# $$
#
# It depends on:
#
# - the **test statistic**
# - the **null distribution**
# - whether the test is **one‑sided or two‑sided**
#
# It is *not* a property of the distribution alone — it’s a property of a **test**.
#
# ---
#
# # 🎯 **Where they overlap**
# For a **one‑sided, upper‑tail test**, the p‑value is literally the survival function evaluated at the observed statistic:
#
# $$
# \text{p-value} = S(x_{\text{obs}})
# $$
#
# So in that special case, the p‑value *equals* the survival function value.
#
# But:
#
# - For **lower‑tail tests**, the p‑value uses the CDF, not the survival function.
# - For **two‑tailed tests**, the p‑value is a combination of both tails.
# - For **non‑continuous distributions**, ties and discreteness complicate the mapping.
# - For **non‑parametric tests**, the p‑value is computed from permutations or ranks, not a survival function.
#
# ---
#
# # 🧭 **Intuitive summary**
# - **Survival function:** “How much probability lies above this point?”
# - **p‑value:** “How surprising is my observed statistic under the null hypothesis?”
#
# They intersect, but they’re not the same concept.
